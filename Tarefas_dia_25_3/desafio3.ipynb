# %% [markdown]
# Exercicio 1
# 1) Aponte a quantidade de vértices e arestas para cada grafo
# a) 5 vertices 8 arestas
# b) 5 vertices 8 arestas
# c) 6 vertices 12 arestas

# %% [markdown]
# Exercicio 2
# a) (a,e) (b,e) (c,e) (d,e)
# b) (a,b) (a,d) (b,c) (c,e) (c,d)
# c) (a,b) (a,d) (a,e) (b,c) (c,d) (c,e)
# d) (a,c) (a,f) (b,c) (b,f) (c,d) (c,e) (e,f)

# %% [markdown]
# Exercicio 3
# {A, B} -> direcional
# {B, E} -> direcional
# {C, B} -> direcional == {C} -> self loop == {C, D} -> multi arestas, {D, C} -> multi arestas
# {E, D} -> direcional == {E, A} -> direcional == {E} -> self loop

# %% [markdown]
# Exercicio 4
# Caminhos possiveis
# a->b->c->d->e->a 15km
# a->b->e->d->c 14km

# %%
import networkx as nx
import matplotlib.pyplot as plt

arestas = [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 3)]

G = nx.DiGraph()

G.add_edges_from(arestas)

nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, font_size=15, font_weight='bold', arrows=True)

plt.title('Grafo Direcionado')
plt.show()
